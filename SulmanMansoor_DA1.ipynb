# %% [markdown]
# # Assignment 1

# %% [markdown]
# ### Assignment Instructions

# %% [markdown]
# * You are **not** allowed to edit any pre-defined variables and as per the instructions for every question you have to assign your answers to these variables.
# * Write your answers in place of `...`

# %% [markdown]
# ### Submission Instructions

# %% [markdown]
# * Rename your notebook as **YourName_DA1.ipynb**. (e.g. *`JohnDoe_DA1.ipynb`*)
#
# * Only submit your notebook named **YourName_DA1.ipynb**

# %%
# Import necessary libraries here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Question 1:** We will begin from the very basics and attempt to create the table below. (`Note:` *name* is ***not*** an index_col)
#
# | name | weight | height | BMI |
# |-----|-----|-----| -----|
# | Max | 110 | 70 | 15.78 |
# | Oliver | 115 | 71 | 16.04 |
# | Tom | 120 | 72 | 16.27 |
# | Harry |125 | 73 | 16.49 |
# | Jasper | 130 | 74 | 16.69 |
# | Finn | 135 | 75 | 16.87 |
# | Felix | 140 | 76 | 17.04 |
# | Asher | 145 | 77 | 17.19 |

# %% [markdown]
# **a:** Generate a series with the names of all the people. Assign it to the variable `name`.

# %%
# Please write your code below
list = ['Max','Oliver','Tom','Harry','Jasper','Finn','Felix','Asher']
name =pd.Series(list)
name
# Out:
# 0       Max
# 1    Oliver
# 2       Tom
# 3     Harry
# 4    Jasper
# 5      Finn
# 6     Felix
# 7     Asher
# dtype: object

# %% [markdown]
# **b:** Generate a series that contains the weight of all the people. Assign it to `weights`. (You are required to use a python function to do this. Hardcoding all values manually is not allowed).

# %%
# Please write your code below
table=[110,115,120,125,130,135,140,145]
weights=pd.Series(table)
weights
# Out:
# 0    110
# 1    115
# 2    120
# 3    125
# 4    130
# 5    135
# 6    140
# 7    145
# dtype: int64

# %% [markdown]
# **c:** Generate a series that contains the height of all the people. Assign it to `heights`. (You are required to use a python function to do this. Hardcoding all values manually is not allowed).

# %%
# Please write your code below
table2=[70,71,72,73,74,75,76,77]
heights = pd.Series(table2)
heights
# Out:
# 0    70
# 1    71
# 2    72
# 3    73
# 4    74
# 5    75
# 6    76
# 7    77
# dtype: int64

# %% [markdown]
# **d:** Using the above series generate a series that contains the BMI of each person. The formula for BMI is as follows:
# $$ BMI = weight (lb) ÷ height^2 (inches) * 703 $$
# Assume that the given weight is in lb and height is in inches. Assign it to the variable `BMI`.  Round your answers to 2 decimal places  (You are not allowed to hardcode).

# %%
# Please write your code below
main=np.array(weights/(heights*heights)*703)
BMI = pd.Series(np.round(main,decimals=2))
print(BMI)
# Out:
# 0    15.78
# 1    16.04
# 2    16.27
# 3    16.49
# 4    16.69
# 5    16.87
# 6    17.04
# 7    17.19
# dtype: float64

# %% [markdown]
# **e:** Finally, use all the above created series to create the dataframe shown above. Assign it to `BMIData`.

# %%
# Please write your code below
BMIData = pd.DataFrame({"name":(name),"weight":(weights),"height":(heights),"BMI":(BMI)})
BMIData
# Out:
#      name  weight  height    BMI
# 0     Max     110      70  15.78
# 1  Oliver     115      71  16.04
# 2     Tom     120      72  16.27
# 3   Harry     125      73  16.49
# 4  Jasper     130      74  16.69
# 5    Finn     135      75  16.87
# 6   Felix     140      76  17.04
# 7   Asher     145      77  17.19

# %% [markdown]
# We have provided you with a data set names `smartphones.csv`. This dataset contains information about various smartphones and their specifications.

# %% [markdown]
# **Question 2:** Read dataset from `smartphones.csv` and assign this dataframe to `smartphoneData`. Print the first 5 rows of the dataset so you know what the data is like:

# %%
# Please write your code below
smartphoneData = pd.read_csv("smartphones.csv")
smartphoneData.head(5)
# Out:
#   brand_name                        Mdl     pc  rating  has_5g  has_nfc  \
# 0    oneplus              OnePlus 11 5G  54999    89.0    True     True
# 1    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0    True    False
# 2    samsung      Samsung Galaxy A14 5G  16499    75.0    True    False
# 3   motorola       Motorola Moto G62 5G  14999    81.0    True    False
# 4     realme         Realme 10 Pro Plus  24999    82.0    True    False
#
#    has_ir_blaster processor_brand  num_cores  processor_speed  ...  \
# 0           False      snapdragon        8.0              3.2  ...
# 1           False      snapdragon        8.0              2.2  ...
# 2           False          exynos        8.0              2.4  ...
# 3           False      snapdragon        8.0              2.2  ...
# 4           False       dimensity        8.0              2.6  ...
#
#    refresh_rate          reso  num_rear_cameras  num_front_cameras       os  \
# 0           120  1440 x 3216                  3                1.0  android
# 1           120  1080 x 2412                  3                1.0  android
# 2            90  1080 x 2408                  3                1.0  android
# 3           120  1080 x 2400                  3                1.0  android
# 4           120  1080 x 2412                  3                1.0  android
#
#    primary_camera_rear  primary_camera_front extended_memory_available  \
# 0                 50.0                  16.0                         0
# 1                 64.0                  16.0                         1
# 2                 50.0                  13.0                         1
# 3                 50.0                  16.0                         1
# 4                108.0                  16.0                         0
#
#    extended_upto  faulty
# 0            NaN       0
# 1         1024.0       0
# 2         1024.0       0
# 3         1024.0       0
# 4            NaN       0
#
# [5 rows x 26 columns]

# %% [markdown]
# **Question 3:** In order to familiarize ourself with the dataset further, it is good to know the shape. Print the shape of the dataset and assign it to the variable `smartphoneDatashape`:

# %%
# Please write your code below
smartphoneDatashape = smartphoneData.shape
print(smartphoneDatashape)
# Out:
# (980, 26)

# %% [markdown]
# **Question 4:** Now that we know the shape of the dataset check if null values are present in it by writing a relevant code snippet that would do the job for you. Store the number of rows with null values, if any, in the variable `smartphoneDfNull`.

# %%
# Please write your code below
##for row in table : 

smartphoneDN = smartphoneData.isnull().sum().sum()
smartphoneDN
# Out:
# 894

# %% [markdown]
# **Question 5a:** If you found any null values (missing values) from the code above, replace all those values with the average value in their respective columns. Do this only for columns containing numeric values. You are allowed to use the built-in mean() function here.

# %%
##y=smartphoneData.select_dtypes(include = ['number'])
##for x in y.columns:
 ##   y.fillna({x: y[x].mean()}, inplace=True)
##y
##new3=y.copy()
df_new=smartphoneData.copy()
for col in df_new.columns:
    if df_new[col].dtype=='number':
        mean_val = df_new[col].mean()
        df_new[col] = df_new[col].fillna(mean_val)

# %% [markdown]
# Now for the rows that still have null values (in the non-numeric columns), drop these rows from the dataframe

# %%
# Please write your code below
##df2=smartphoneData.copy()
##for col in df2.columns:
  ##  if df2[col].dtype=='number':
    ##    mean_val = df2[col].mean()
      ##  df2[col] = df2[col].fillna(mean_val)
    ##else:
     ##   df2.dropna(inplace=True)
df_new2=df_new.copy()
df_new2.dropna(inplace=True)
df_new2
# Out:
#     brand_name                                      Mdl     pc  rating  \
# 1      oneplus                OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      samsung                    Samsung Galaxy A14 5G  16499    75.0
# 5      samsung  Samsung Galaxy F23 5G (6GB RAM + 128GB)  16999    80.0
# 10      realme                            Realme 10 Pro  18999    82.0
# 13        vivo             Vivo T1 5G (6GB RAM + 128GB)  16990    80.0
# ..         ...                                      ...    ...     ...
# 944     realme                          Realme Narzo 20  10499    72.0
# 961       oppo                                OPPO A58x  13990    72.0
# 962     doogee                               Doogee S99  14999    84.0
# 970     realme  Realme Narzo 50i Prime (4GB RAM + 64GB)   8720    64.0
# 976      honor                              Honor X8 5G  14990    75.0
#
#      has_5g  has_nfc  has_ir_blaster processor_brand  num_cores  \
# 1      True    False           False      snapdragon        8.0
# 2      True    False           False          exynos        8.0
# 5      True     True           False      snapdragon        8.0
# 10     True    False           False      snapdragon        8.0
# 13     True    False           False      snapdragon        8.0
# ..      ...      ...             ...             ...        ...
# 944   False    False           False           helio        8.0
# 961    True    False           False       dimensity        8.0
# 962   False     True           False           helio        8.0
# 970   False    False           False           tiger        8.0
# 976    True    False           False      snapdragon        8.0
#
#      processor_speed  ...  refresh_rate          reso  num_rear_cameras  \
# 1               2.20  ...           120  1080 x 2412                  3
# 2               2.40  ...            90  1080 x 2408                  3
# 5               2.20  ...           120  1080 x 2408                  3
# 10              2.20  ...           120  1080 x 2400                  2
# 13              2.20  ...           120  1080 x 2408                  3
# ..               ...  ...           ...           ...               ...
# 944             2.00  ...            60   720 x 1600                  3
# 961             2.20  ...            90   720 x 1612                  2
# 962             2.05  ...            60  1080 x 2340                  3
# 970             1.82  ...            60   720 x 1600                  1
# 976             2.20  ...            60   720 x 1600                  3
#
#      num_front_cameras       os  primary_camera_rear  primary_camera_front  \
# 1                  1.0  android                 64.0                  16.0
# 2                  1.0  android                 50.0                  13.0
# 5                  1.0  android                 50.0                   8.0
# 10                 1.0  android                108.0                  16.0
# 13                 1.0  android                 50.0                  16.0
# ..                 ...      ...                  ...                   ...
# 944                1.0  android                 48.0                   8.0
# 961                1.0  android                 13.0                   8.0
# 962                1.0  android                108.0                  32.0
# 970                1.0  android                  8.0                   5.0
# 976                1.0  android                 48.0                   8.0
#
#     extended_memory_available  extended_upto  faulty
# 1                           1         1024.0       0
# 2                           1         1024.0       0
# 5                           1         1024.0       0
# 10                          1         1024.0       0
# 13                          1         1024.0       0
# ..                        ...            ...     ...
# 944                         1          256.0       1
# 961                         1         1024.0       0
# 962                         1         1024.0       0
# 970                         1         1024.0       1
# 976                         1         1024.0       0
#
# [352 rows x 26 columns]

# %% [markdown]
# **Question 5b:** A good data scientist needs to be able to justify his/her choices. Do you think this was a good way of dealing with missing values? Why or why not?

# %%
## Write your answer here:
## Replacing and Removing NULL values from DataSet is very important for accurate and precise statistical analysis on dataset as NULL values can bring BIAS in analysis and give inaccurate results

# %% [markdown]
# **Question 6:** While going through the dataframe, you might have noticed some discrepancies in the column names. We will rename these columns so that we can make more sense out of the data and comprehend it in a better way. The following column changes must be reflected in the dataframe.
# <ul>
#
# <li>Mdl --> model</li>
# <li> pc --> price</li>
# <li>reso --> res </li>
#  <li> primary_camera_rear --> rear_megapixels</li>
#      <li> primary_camera_front --> front_megapixels</li>
# </ul>
#
# You should also drop the `rating` column.

# %%
## Please write your code below
df_new3=df_new2.copy()
df_new3.rename(columns={"Mdl":"model","pc":"price","reso":"res","primary_camera_rear":"rear_megapixels","primary_camera_front":"front_megapixels"},inplace='True')
df_new4=df_new3.drop(['rating'],axis=1)
df_new4
# Out:
#     brand_name                                    model  price  has_5g  \
# 1      oneplus                OnePlus Nord CE 2 Lite 5G  19989    True
# 2      samsung                    Samsung Galaxy A14 5G  16499    True
# 5      samsung  Samsung Galaxy F23 5G (6GB RAM + 128GB)  16999    True
# 10      realme                            Realme 10 Pro  18999    True
# 13        vivo             Vivo T1 5G (6GB RAM + 128GB)  16990    True
# ..         ...                                      ...    ...     ...
# 944     realme                          Realme Narzo 20  10499   False
# 961       oppo                                OPPO A58x  13990    True
# 962     doogee                               Doogee S99  14999   False
# 970     realme  Realme Narzo 50i Prime (4GB RAM + 64GB)   8720   False
# 976      honor                              Honor X8 5G  14990    True
#
#      has_nfc  has_ir_blaster processor_brand  num_cores  processor_speed  \
# 1      False           False      snapdragon        8.0             2.20
# 2      False           False          exynos        8.0             2.40
# 5       True           False      snapdragon        8.0             2.20
# 10     False           False      snapdragon        8.0             2.20
# 13     False           False      snapdragon        8.0             2.20
# ..       ...             ...             ...        ...              ...
# 944    False           False           helio        8.0             2.00
# 961    False           False       dimensity        8.0             2.20
# 962     True           False           helio        8.0             2.05
# 970    False           False           tiger        8.0             1.82
# 976    False           False      snapdragon        8.0             2.20
#
#      battery_capacity  ...  refresh_rate           res  num_rear_cameras  \
# 1              5000.0  ...           120  1080 x 2412                  3
# 2              5000.0  ...            90  1080 x 2408                  3
# 5              5000.0  ...           120  1080 x 2408                  3
# 10             5000.0  ...           120  1080 x 2400                  2
# 13             5000.0  ...           120  1080 x 2408                  3
# ..                ...  ...           ...           ...               ...
# 944            6000.0  ...            60   720 x 1600                  3
# 961            5000.0  ...            90   720 x 1612                  2
# 962            6000.0  ...            60  1080 x 2340                  3
# 970            5000.0  ...            60   720 x 1600                  1
# 976            5000.0  ...            60   720 x 1600                  3
#
#      num_front_cameras       os  rear_megapixels front_megapixels  \
# 1                  1.0  android             64.0             16.0
# 2                  1.0  android             50.0             13.0
# 5                  1.0  android             50.0              8.0
# 10                 1.0  android            108.0             16.0
# 13                 1.0  android             50.0             16.0
# ..                 ...      ...              ...              ...
# 944                1.0  android             48.0              8.0
# 961                1.0  android             13.0              8.0
# 962                1.0  android            108.0             32.0
# 970                1.0  android              8.0              5.0
# 976                1.0  android             48.0              8.0
#
#      extended_memory_available  extended_upto faulty
# 1                            1         1024.0      0
# 2                            1         1024.0      0
# 5                            1         1024.0      0
# 10                           1         1024.0      0
# 13                           1         1024.0      0
# ..                         ...            ...    ...
# 944                          1          256.0      1
# 961                          1         1024.0      0
# 962                          1         1024.0      0
# 970                          1         1024.0      1
# 976                          1         1024.0      0
#
# [352 rows x 25 columns]

# %% [markdown]
# **Question 7:** There are some columns which have values of either `True` or `False`. Write a code snippet to replace these values with a 1 or a 0 respectively.

# %%
# Please write your code below
df_new5=df_new4.copy()
for col2 in df_new5.columns:
    if df_new5[col2].dtype=='bool':
        df_new5[col2].replace({True:1})
        df_new5[col2].replace({False:0})
##df_new5=df_new4.copy()
##df_new6=df_new5.replace({True,1})
##df_new5.replace('False',0)
df_new5
# Out:
#     brand_name                                    model  price  has_5g  \
# 1      oneplus                OnePlus Nord CE 2 Lite 5G  19989    True
# 2      samsung                    Samsung Galaxy A14 5G  16499    True
# 5      samsung  Samsung Galaxy F23 5G (6GB RAM + 128GB)  16999    True
# 10      realme                            Realme 10 Pro  18999    True
# 13        vivo             Vivo T1 5G (6GB RAM + 128GB)  16990    True
# ..         ...                                      ...    ...     ...
# 944     realme                          Realme Narzo 20  10499   False
# 961       oppo                                OPPO A58x  13990    True
# 962     doogee                               Doogee S99  14999   False
# 970     realme  Realme Narzo 50i Prime (4GB RAM + 64GB)   8720   False
# 976      honor                              Honor X8 5G  14990    True
#
#      has_nfc  has_ir_blaster processor_brand  num_cores  processor_speed  \
# 1      False           False      snapdragon        8.0             2.20
# 2      False           False          exynos        8.0             2.40
# 5       True           False      snapdragon        8.0             2.20
# 10     False           False      snapdragon        8.0             2.20
# 13     False           False      snapdragon        8.0             2.20
# ..       ...             ...             ...        ...              ...
# 944    False           False           helio        8.0             2.00
# 961    False           False       dimensity        8.0             2.20
# 962     True           False           helio        8.0             2.05
# 970    False           False           tiger        8.0             1.82
# 976    False           False      snapdragon        8.0             2.20
#
#      battery_capacity  ...  refresh_rate           res  num_rear_cameras  \
# 1              5000.0  ...           120  1080 x 2412                  3
# 2              5000.0  ...            90  1080 x 2408                  3
# 5              5000.0  ...           120  1080 x 2408                  3
# 10             5000.0  ...           120  1080 x 2400                  2
# 13             5000.0  ...           120  1080 x 2408                  3
# ..                ...  ...           ...           ...               ...
# 944            6000.0  ...            60   720 x 1600                  3
# 961            5000.0  ...            90   720 x 1612                  2
# 962            6000.0  ...            60  1080 x 2340                  3
# 970            5000.0  ...            60   720 x 1600                  1
# 976            5000.0  ...            60   720 x 1600                  3
#
#      num_front_cameras       os  rear_megapixels front_megapixels  \
# 1                  1.0  android             64.0             16.0
# 2                  1.0  android             50.0             13.0
# 5                  1.0  android             50.0              8.0
# 10                 1.0  android            108.0             16.0
# 13                 1.0  android             50.0             16.0
# ..                 ...      ...              ...              ...
# 944                1.0  android             48.0              8.0
# 961                1.0  android             13.0              8.0
# 962                1.0  android            108.0             32.0
# 970                1.0  android              8.0              5.0
# 976                1.0  android             48.0              8.0
#
#      extended_memory_available  extended_upto faulty
# 1                            1         1024.0      0
# 2                            1         1024.0      0
# 5                            1         1024.0      0
# 10                           1         1024.0      0
# 13                           1         1024.0      0
# ..                         ...            ...    ...
# 944                          1          256.0      1
# 961                          1         1024.0      0
# 962                          1         1024.0      0
# 970                          1         1024.0      1
# 976                          1         1024.0      0
#
# [352 rows x 25 columns]

# %% [markdown]
# **Question 8:** Now that we have understood the whole dataframe and tweaked it up to make it more comprehensible, set the index of the data frame to `brand_name`

# %%
# Please write your code below
df_new7=df_new5.copy()
df_new7.set_index('brand_name')
# Out:
#                                               model  price  has_5g  has_nfc  \
# brand_name
# oneplus                   OnePlus Nord CE 2 Lite 5G  19989    True    False
# samsung                       Samsung Galaxy A14 5G  16499    True    False
# samsung     Samsung Galaxy F23 5G (6GB RAM + 128GB)  16999    True     True
# realme                                Realme 10 Pro  18999    True    False
# vivo                   Vivo T1 5G (6GB RAM + 128GB)  16990    True    False
# ...                                             ...    ...     ...      ...
# realme                              Realme Narzo 20  10499   False    False
# oppo                                      OPPO A58x  13990    True    False
# doogee                                   Doogee S99  14999   False     True
# realme      Realme Narzo 50i Prime (4GB RAM + 64GB)   8720   False    False
# honor                                   Honor X8 5G  14990    True    False
#
#             has_ir_blaster processor_brand  num_cores  processor_speed  \
# brand_name
# oneplus              False      snapdragon        8.0             2.20
# samsung              False          exynos        8.0             2.40
# samsung              False      snapdragon        8.0             2.20
# realme               False      snapdragon        8.0             2.20
# vivo                 False      snapdragon        8.0             2.20
# ...                    ...             ...        ...              ...
# realme               False           helio        8.0             2.00
# oppo                 False       dimensity        8.0             2.20
# doogee               False           helio        8.0             2.05
# realme               False           tiger        8.0             1.82
# honor                False      snapdragon        8.0             2.20
#
#             battery_capacity  fast_charging_available  ...  refresh_rate  \
# brand_name                                             ...
# oneplus               5000.0                        1  ...           120
# samsung               5000.0                        1  ...            90
# samsung               5000.0                        1  ...           120
# realme                5000.0                        1  ...           120
# vivo                  5000.0                        1  ...           120
# ...                      ...                      ...  ...           ...
# realme                6000.0                        1  ...            60
# oppo                  5000.0                        1  ...            90
# doogee                6000.0                        1  ...            60
# realme                5000.0                        1  ...            60
# honor                 5000.0                        1  ...            60
#
#                      res  num_rear_cameras  num_front_cameras       os  \
# brand_name
# oneplus     1080 x 2412                  3                1.0  android
# samsung     1080 x 2408                  3                1.0  android
# samsung     1080 x 2408                  3                1.0  android
# realme      1080 x 2400                  2                1.0  android
# vivo        1080 x 2408                  3                1.0  android
# ...                  ...               ...                ...      ...
# realme       720 x 1600                  3                1.0  android
# oppo         720 x 1612                  2                1.0  android
# doogee      1080 x 2340                  3                1.0  android
# realme       720 x 1600                  1                1.0  android
# honor        720 x 1600                  3                1.0  android
#
#            rear_megapixels  front_megapixels  extended_memory_available  \
# brand_name
# oneplus               64.0              16.0                          1
# samsung               50.0              13.0                          1
# samsung               50.0               8.0                          1
# realme               108.0              16.0                          1
# vivo                  50.0              16.0                          1
# ...                    ...               ...                        ...
# realme                48.0               8.0                          1
# oppo                  13.0               8.0                          1
# doogee               108.0              32.0                          1
# realme                 8.0               5.0                          1
# honor                 48.0               8.0                          1
#
#            extended_upto  faulty
# brand_name
# oneplus           1024.0       0
# samsung           1024.0       0
# samsung           1024.0       0
# realme            1024.0       0
# vivo              1024.0       0
# ...                  ...     ...
# realme             256.0       1
# oppo              1024.0       0
# doogee            1024.0       0
# realme            1024.0       1
# honor             1024.0       0
#
# [352 rows x 24 columns]

# %% [markdown]
# **Question 9a:** Saad needs to buy a new phone and as a data scientist, he has selected you to help him make a decision. His maximum budget is 50,000 rupees. However, he does not want to trade off quality for a phone that is too cheap. Filter out all the phones that fall within his budget constraint but also cost at least 15,000 rupees, and store it in the variable `filteredPhones`.

# %%
# Please write your code below
filteredPhones=df_new7.copy()
filteredPhones.query('price<50000' and 'price>15000')
# Out:
#     brand_name                                        model  price  has_5g  \
# 1      oneplus                    OnePlus Nord CE 2 Lite 5G  19989    True
# 2      samsung                        Samsung Galaxy A14 5G  16499    True
# 5      samsung      Samsung Galaxy F23 5G (6GB RAM + 128GB)  16999    True
# 10      realme                                Realme 10 Pro  18999    True
# 13        vivo                 Vivo T1 5G (6GB RAM + 128GB)  16990    True
# ..         ...                                          ...    ...     ...
# 921     xiaomi  Xiaomi 11i HyperCharge 5G (8GB RAM + 128GB)  26999    True
# 922    samsung      Samsung Galaxy F42 5G (8GB RAM + 128GB)  22999    True
# 928       oppo                                 Oppo Reno 5A  22990    True
# 935    samsung                           Samsung Galaxy A22  18499   False
# 939    samsung         Samsung Galaxy F41 (6GB RAM + 128GB)  19999   False
#
#      has_nfc  has_ir_blaster processor_brand  num_cores  processor_speed  \
# 1      False           False      snapdragon        8.0              2.2
# 2      False           False          exynos        8.0              2.4
# 5       True           False      snapdragon        8.0              2.2
# 10     False           False      snapdragon        8.0              2.2
# 13     False           False      snapdragon        8.0              2.2
# ..       ...             ...             ...        ...              ...
# 921    False            True       dimensity        8.0              2.5
# 922    False           False       dimensity        8.0              2.2
# 928    False           False      snapdragon        8.0              2.4
# 935    False           False           helio        8.0              2.0
# 939    False           False          exynos        8.0              2.3
#
#      battery_capacity  ...  refresh_rate           res  num_rear_cameras  \
# 1              5000.0  ...           120  1080 x 2412                  3
# 2              5000.0  ...            90  1080 x 2408                  3
# 5              5000.0  ...           120  1080 x 2408                  3
# 10             5000.0  ...           120  1080 x 2400                  2
# 13             5000.0  ...           120  1080 x 2408                  3
# ..                ...  ...           ...           ...               ...
# 921            4500.0  ...           120  2400 x 1080                  3
# 922            5000.0  ...            90  1080 x 2408                  3
# 928            4000.0  ...            90  1080 x 2400                  4
# 935            5000.0  ...            60   720 x 1600                  4
# 939            6000.0  ...            60  1080 x 2340                  3
#
#      num_front_cameras       os  rear_megapixels front_megapixels  \
# 1                  1.0  android             64.0             16.0
# 2                  1.0  android             50.0             13.0
# 5                  1.0  android             50.0              8.0
# 10                 1.0  android            108.0             16.0
# 13                 1.0  android             50.0             16.0
# ..                 ...      ...              ...              ...
# 921                1.0  android            108.0             16.0
# 922                1.0  android             64.0              8.0
# 928                1.0  android             64.0             16.0
# 935                1.0  android             48.0             13.0
# 939                1.0  android             64.0             32.0
#
#      extended_memory_available  extended_upto faulty
# 1                            1         1024.0      0
# 2                            1         1024.0      0
# 5                            1         1024.0      0
# 10                           1         1024.0      0
# 13                           1         1024.0      0
# ..                         ...            ...    ...
# 921                          1         1024.0      0
# 922                          1         1024.0      0
# 928                          1         1024.0      0
# 935                          1         1024.0      0
# 939                          1          512.0      1
#
# [196 rows x 25 columns]

# %% [markdown]
# **Question 9b:** Next, saad gives you a list which contains preference values for certain smartphone features:
#
# | feature | preference value |
# |-----|-----|
# | number of cores | 3 |
# | battery capacity | 5 |
# | screen size | 2 |
# | refresh rate | 3 |
# | ram capacity | 4 |
# | internal memory | 5 |
# | processor speed | 4 |
# | rear camera megapixels | 3 |
# | front camera megapixels | 2 |
#
# Write a function `calculate` that takes a full row from the filtered dataset as a parameter and returns the score for the phone in that row by multiplying the preference values with the corresponding characterstics. **Hint:** There is a certain function which helps you print all column names in order (just in case you need to find their index)

# %%
# Please write your code below

def calculate(i):
    for index, row in df_new8.loc[i:i, ['num_cores', 'battery_capacity','screen_size','refresh_rate','ram_capacity','internal_memory','processor_speed','rear_megapixels','front_megapixels']].iterrows():
        score=row['num_cores']*3+row['battery_capacity']*5+row['screen_size']*2+row['refresh_rate']*3+row['ram_capacity']*4+row['internal_memory']*5+row['processor_speed']*4+row['rear_megapixels']*3+row['front_megapixels']*2
    return(score)

# %% [markdown]
# **Question 9c** Make a new dataframe with scores for each of the filtered phones along with their price, os and processor brand . Note: Order should be `score`, `price`, `os`,`processor_brand` with `model` as index. Assign it to `phoneScores`.

# %%
# Please write your code below

df_new8=filteredPhones.copy()
for index, row in df_new8.iterrows():
    b=calculate(row)
    ##phoneScores = pd.DataFrame({"score":[b],"price":[df_new8.loc[row,"price"]],"os":[df_new8.loc[row,"os"]],"processor_brand":[df_new8.loc[row,"processor_brand"]],"model":[df_new8.loc[row,"model"]]})  
    phoneScores = pd.DataFrame({"score":[b],"price":[row["price"]],"os":[row["os"]],"processor_brand":[row["processor_brand"]],"model":[row["model"]]})  
phoneScores
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File C:\PRESALES-JULY2023\BACKUP_PRESALES_JULY2023\PRESALES\ANACONDA\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:173, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: 'brand_name                                     oneplus
# model                        OnePlus Nord CE 2 Lite 5G
# price                                            19989
# has_5g                                            True
# has_nfc                                          False
# has_ir_blaster                                   False
# processor_brand                             snapdragon
# num_cores                                          8.0
# processor_speed                                    2.2
# battery_capacity                                5000.0
# fast_charging_available                              1
# fast_charging                                     33.0
# ram_capacity                                         6
# internal_memory                                    128
# screen_size                                       6.59
# refresh_rate                                       120
# res                                       1080 x 2412
# num_rear_cameras                                     3
# num_front_cameras                                  1.0
# os                                             android
# rear_megapixels                                   64.0
# front_megapixels                                  16.0
# extended_memory_available                            1
# extended_upto                                   1024.0
# faulty                                               0
# Name: 1, dtype: object' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[91], line 5
#       3 df_new8=filteredPhones.copy()
#       4 for index, row in df_new8.iterrows():
# ----> 5     b=calculate(row)
#       6     ##phoneScores = pd.DataFrame({"score":[b],"price":[df_new8.loc[row,"price"]],"os":[df_new8.loc[row,"os"]],"processor_brand":[df_new8.loc[row,"processor_brand"]],"model":[df_new8.loc[row,"model"]]})
#       7     phoneScores = pd.DataFrame({"score":[b],"price":[row["price"]],"os":[row["os"]],"processor_brand":[row["processor_brand"]],"model":[row["model"]]})
#
# Cell In[39], line 4, in calculate(i)
#       3 def calculate(i):
# ----> 4     for index, row in df_new8.loc[i:i, ['num_cores', 'battery_capacity','screen_size','refresh_rate','ram_capacity','internal_memory','processor_speed','rear_megapixels','front_megapixels']].iterrows():
#       5         score=row['num_cores']*3+row['battery_capacity']*5+row['screen_size']*2+row['refresh_rate']*3+row['ram_capacity']*4+row['internal_memory']*5+row['processor_speed']*4+row['rear_megapixels']*3+row['front_megapixels']*2
#       6     return(score)
#
# File C:\PRESALES-JULY2023\BACKUP_PRESALES_JULY2023\PRESALES\ANACONDA\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File C:\PRESALES-JULY2023\BACKUP_PRESALES_JULY2023\PRESALES\ANACONDA\Lib\site-packages\pandas\core\indexing.py:1377, in _LocIndexer._getitem_tuple(self, tup)
#    1374 if self._multi_take_opportunity(tup):
#    1375     return self._multi_take(tup)
# -> 1377 return self._getitem_tuple_same_dim(tup)
#
# File C:\PRESALES-JULY2023\BACKUP_PRESALES_JULY2023\PRESALES\ANACONDA\Lib\site-packages\pandas\core\indexing.py:1020, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
#    1017 if com.is_null_slice(key):
#    1018     continue
# -> 1020 retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#    1021 # We should never have retval.ndim < self.ndim, as that should
#    1022 #  be handled by the _getitem_lowerdim call above.
#    1023 assert retval.ndim == self.ndim
#
# File C:\PRESALES-JULY2023\BACKUP_PRESALES_JULY2023\PRESALES\ANACONDA\Lib\site-packages\pandas\core\indexing.py:1411, in _LocIndexer._getitem_axis(self, key, axis)
#    1409 if isinstance(key, slice):
#    1410     self._validate_key(key, axis)
# -> 1411     return self._get_slice_axis(key, axis=axis)
#    1412 elif com.is_bool_indexer(key):
#    1413     return self._getbool_axis(key, axis=axis)
#
# File C:\PRESALES-JULY2023\BACKUP_PRESALES_JULY2023\PRESALES\ANACONDA\Lib\site-packages\pandas\core\indexing.py:1443, in _LocIndexer._get_slice_axis(self, slice_obj, axis)
#    1440     return obj.copy(deep=False)
#    1442 labels = obj._get_axis(axis)
# -> 1443 indexer = labels.slice_indexer(slice_obj.start, slice_obj.stop, slice_obj.step)
#    1445 if isinstance(indexer, slice):
#    1446     return self.obj._slice(indexer, axis=axis)
#
# File C:\PRESALES-JULY2023\BACKUP_PRESALES_JULY2023\PRESALES\ANACONDA\Lib\site-packages\pandas\core\indexes\base.py:6662, in Index.slice_indexer(self, start, end, step)
#    6618 def slice_indexer(
#    6619     self,
#    6620     start: Hashable | None = None,
#    6621     end: Hashable | None = None,
#    6622     step: int | None = None,
#    6623 ) -> slice:
#    6624     """
#    6625     Compute the slice indexer for input labels and step.
#    6626
#    (...)
#    6660     slice(1, 3, None)
#    6661     """
# -> 6662     start_slice, end_slice = self.slice_locs(start, end, step=step)
#    6664     # return a slice
#    6665     if not is_scalar(start_slice):
#
# File C:\PRESALES-JULY2023\BACKUP_PRESALES_JULY2023\PRESALES\ANACONDA\Lib\site-packages\pandas\core\indexes\base.py:6879, in Index.slice_locs(self, start, end, step)
#    6877 start_slice = None
#    6878 if start is not None:
# -> 6879     start_slice = self.get_slice_bound(start, "left")
#    6880 if start_slice is None:
#    6881     start_slice = 0
#
# File C:\PRESALES-JULY2023\BACKUP_PRESALES_JULY2023\PRESALES\ANACONDA\Lib\site-packages\pandas\core\indexes\base.py:6798, in Index.get_slice_bound(self, label, side)
#    6796 # we need to look up the label
#    6797 try:
# -> 6798     slc = self.get_loc(label)
#    6799 except KeyError as err:
#    6800     try:
#
# File C:\PRESALES-JULY2023\BACKUP_PRESALES_JULY2023\PRESALES\ANACONDA\Lib\site-packages\pandas\core\indexes\base.py:3817, in Index.get_loc(self, key)
#    3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
# -> 3817     self._check_indexing_error(key)
#    3818     raise
#
# File C:\PRESALES-JULY2023\BACKUP_PRESALES_JULY2023\PRESALES\ANACONDA\Lib\site-packages\pandas\core\indexes\base.py:6059, in Index._check_indexing_error(self, key)
#    6055 def _check_indexing_error(self, key):
#    6056     if not is_scalar(key):
#    6057         # if key is not a scalar, directly raise an error (the code below
#    6058         # would convert to numpy arrays and raise later any way) - GH29926
# -> 6059         raise InvalidIndexError(key)
#
# InvalidIndexError: brand_name                                     oneplus
# model                        OnePlus Nord CE 2 Lite 5G
# price                                            19989
# has_5g                                            True
# has_nfc                                          False
# has_ir_blaster                                   False
# processor_brand                             snapdragon
# num_cores                                          8.0
# processor_speed                                    2.2
# battery_capacity                                5000.0
# fast_charging_available                              1
# fast_charging                                     33.0
# ram_capacity                                         6
# internal_memory                                    128
# screen_size                                       6.59
# refresh_rate                                       120
# res                                       1080 x 2412
# num_rear_cameras                                     3
# num_front_cameras                                  1.0
# os                                             android
# rear_megapixels                                   64.0
# front_megapixels                                  16.0
# extended_memory_available                            1
# extended_upto                                   1024.0
# faulty                                               0
# Name: 1, dtype: object

# %% [markdown]
# **Question 9d** Using a pivot table, count the number of different processor brands each operating system (os) has. **Note:** Keep the operating system as the column. Assign the pivot table to the variable `pivotTable`

# %%
# Please write your code below
##df_new8.columns
##pivotTable = ...
# Out:
#     brand_name                                    model  price  has_5g  \
# 1      oneplus                OnePlus Nord CE 2 Lite 5G  19989    True
# 2      samsung                    Samsung Galaxy A14 5G  16499    True
# 5      samsung  Samsung Galaxy F23 5G (6GB RAM + 128GB)  16999    True
# 10      realme                            Realme 10 Pro  18999    True
# 13        vivo             Vivo T1 5G (6GB RAM + 128GB)  16990    True
# ..         ...                                      ...    ...     ...
# 944     realme                          Realme Narzo 20  10499   False
# 961       oppo                                OPPO A58x  13990    True
# 962     doogee                               Doogee S99  14999   False
# 970     realme  Realme Narzo 50i Prime (4GB RAM + 64GB)   8720   False
# 976      honor                              Honor X8 5G  14990    True
#
#      has_nfc  has_ir_blaster processor_brand  num_cores  processor_speed  \
# 1      False           False      snapdragon        8.0             2.20
# 2      False           False          exynos        8.0             2.40
# 5       True           False      snapdragon        8.0             2.20
# 10     False           False      snapdragon        8.0             2.20
# 13     False           False      snapdragon        8.0             2.20
# ..       ...             ...             ...        ...              ...
# 944    False           False           helio        8.0             2.00
# 961    False           False       dimensity        8.0             2.20
# 962     True           False           helio        8.0             2.05
# 970    False           False           tiger        8.0             1.82
# 976    False           False      snapdragon        8.0             2.20
#
#      battery_capacity  ...  refresh_rate           res  num_rear_cameras  \
# 1              5000.0  ...           120  1080 x 2412                  3
# 2              5000.0  ...            90  1080 x 2408                  3
# 5              5000.0  ...           120  1080 x 2408                  3
# 10             5000.0  ...           120  1080 x 2400                  2
# 13             5000.0  ...           120  1080 x 2408                  3
# ..                ...  ...           ...           ...               ...
# 944            6000.0  ...            60   720 x 1600                  3
# 961            5000.0  ...            90   720 x 1612                  2
# 962            6000.0  ...            60  1080 x 2340                  3
# 970            5000.0  ...            60   720 x 1600                  1
# 976            5000.0  ...            60   720 x 1600                  3
#
#      num_front_cameras       os  rear_megapixels front_megapixels  \
# 1                  1.0  android             64.0             16.0
# 2                  1.0  android             50.0             13.0
# 5                  1.0  android             50.0              8.0
# 10                 1.0  android            108.0             16.0
# 13                 1.0  android             50.0             16.0
# ..                 ...      ...              ...              ...
# 944                1.0  android             48.0              8.0
# 961                1.0  android             13.0              8.0
# 962                1.0  android            108.0             32.0
# 970                1.0  android              8.0              5.0
# 976                1.0  android             48.0              8.0
#
#      extended_memory_available  extended_upto faulty
# 1                            1         1024.0      0
# 2                            1         1024.0      0
# 5                            1         1024.0      0
# 10                           1         1024.0      0
# 13                           1         1024.0      0
# ..                         ...            ...    ...
# 944                          1          256.0      1
# 961                          1         1024.0      0
# 962                          1         1024.0      0
# 970                          1         1024.0      1
# 976                          1         1024.0      0
#
# [352 rows x 25 columns]

# %% [markdown]
# **Question 9e** Using the phoneScores dataframe, Saad wants you to check for the most popular processor brand. Create a horizontal bar plot, where the y-axis contains each processor brand and the x-axis contains the number of phones using that brand of processor. Then write a code snippet to find the most popular brand and store this in the variable `most_popular_processor`

# %%
# Please write your code below
df_new8.loc[10:10, ['num_cores', 'battery_capacity','screen_size','refresh_rate','ram_capacity','internal_memory','processor_speed','rear_megapixels','front_megapixels']]
##most_popular_processor = ...
# Out:
#     num_cores  battery_capacity  screen_size  refresh_rate  ram_capacity  \
# 10        8.0            5000.0         6.72           120             6
#
#     internal_memory  processor_speed  rear_megapixels  front_megapixels
# 10              128              2.2            108.0              16.0

# %% [markdown]
# **Question 9f** Saad now decides that he only wants an android phone with the most popular processor. Filter your results from the `phoneScores` dataframe to find phones with android operating systems and the processor brand you shortlisted in Q9e and store them in the variable `androidPhones`.

# %%
# Please write your code below

androidPhones = ...

# %% [markdown]
# **Question 9g** Finally, from these filtered android phones, find out the top 5 phones with the highest scores. Plot a bar chart for these phones with their model on the x axis and price on the y axis.

# %%
# Please write your code below
...

# %% [markdown]
# **Question 9h** From these top 5 phones, Saad wants to buy the cheapest one. Use a python function to find the cheapest phone from these top 5 phones. Then visually find the cheapest phone from your bar chart. Do they match? If so, store the model name in the variable `finalPhone`.

# %%
# Please write your code below

finalPhone = ...

# %% [markdown]
# **Question 10** Using the original dataset `smartPhoneData`, find out if the average price of Android phones is higher than apple (ios) Phones. Make a variable names `higher_price` and store the string `Yes` or `No` in it depending on your answer. `Yes` indicating that Android phones are more expensive, on average.

# %%
# Please write your code below

higher_price = ...

# %% [markdown]
# **Question 11** How many phones have a price and battery capacity below the thresholds mentioned below? Store it in the variable `numberOfPhones`. (Use the original dataset)
# <br>
# The column `faulty` in the original dataset indicates if a phone has known faults or not. `1` indicates there are known faults and `0` indicates there are no known faults.
# Do you think phones with a lower price and battery capacity than the threshold have a higher probability of getting a fault? Justify this claim by providing a valid analysis.

# %%
priceThreshold = 50000
batteryThreshold = 3000

# Please write your code below

numberOfPhones = ...

## Provide an explanation for your answer below
## ...

# %% [markdown]
# End of Assignment 01 🙏
